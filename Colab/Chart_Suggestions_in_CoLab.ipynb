# %% [markdown]
# <a href="https://colab.research.google.com/github/rendzina/BigDataAndVisualisation/blob/main/Colab/Chart_Suggestions_in_CoLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using visualisation suggestions in Google Co-Lab
# *MKU: Big Data and Visualisation*
# ## Instructions
# 1. Load an online csv file into a Pandas dataframe
# Here we load data.gov.uk data on UK greenhouse gas emissions: local authority and regional, from https://www.data.gov.uk/dataset/723c243d-2f1a-4d27-8b61-cdb93e5b10ff/local_authority_carbon_dioxide_emissions
# 2. In Colab, end the code cell with the name of the dataframe (here 'df') on its own
# 3. Run the cell
# 4, See the suggest charts icon that appears on the far right side
# 5. Run this to see a selection of suggested charts
# 6. Select one to work with. CoLab shows you the graph and presents the code to build the visualisation

# %%
import pandas as pd
import numpy as nd
url = "https://assets.publishing.service.gov.uk/media/68653c7ee6c3cc924228943f/2005-23-uk-local-authority-ghg-emissions-CSV-dataset.csv"
df = pd.read_csv(url)
df
# Out:
#         Country Country Code      Region Region Code Second Tier Authority  \
# 0       England    E92000001  North East   E12000001            Hartlepool
# 1       England    E92000001  North East   E12000001            Hartlepool
# 2       England    E92000001  North East   E12000001            Hartlepool
# 3       England    E92000001  North East   E12000001            Hartlepool
# 4       England    E92000001  North East   E12000001            Hartlepool
# ...         ...          ...         ...         ...                   ...
# 559210    Wales    W92000004       Wales   W92000004                 Wales
# 559211    Wales    W92000004       Wales   W92000004                 Wales
# 559212    Wales    W92000004       Wales   W92000004                 Wales
# 559213    Wales    W92000004       Wales   W92000004                 Wales
# 559214    Wales    W92000004       Wales   W92000004                 Wales
#
# ...
